# %%
import pandas as pd

# %% [markdown]
# # Table 2 | Benchmark

# %%
from analysis import table2

result = pd.read_csv('benchmark.csv')

table2(result)
# Out:
#                               f1                                          \
#                             mean                           std
# dataset                      MSL      SMAP       SMD       MSL      SMAP
# pipeline
# M2AD                    0.748987  0.716001  0.903239  0.031704  0.021257
# OA                      0.562038  0.576728  0.576469  0.079027  0.047069
# USAD                    0.699657  0.650173  0.608347  0.083093  0.111131
# anomaly_transformer     0.390519  0.359102  0.533390  0.039358  0.030617
# fits                    0.385638  0.135936  0.315733  0.010966  0.006882
# lstm_autoencoder        0.493198  0.671877  0.401542  0.051593  0.025378
# lstm_dynamic_threshold  0.482652  0.713053  0.432605  0.013507  0.018255
# timesnet                0.276198  0.168755  0.409391  0.038190  0.017845
# vae                     0.492229  0.648587  0.412121  0.019666  0.010987
#
#                                        f05                                \
# ...

# %% [markdown]
# # Figure 3 | Error Functions

# %%
from analysis import figure3

result = pd.read_csv('error_ablation.csv')

figure3(result)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Figure 4a | Interpretability

# %%
from analysis import figure4a

result = pd.read_csv('contribution.csv')

figure4a(result)
